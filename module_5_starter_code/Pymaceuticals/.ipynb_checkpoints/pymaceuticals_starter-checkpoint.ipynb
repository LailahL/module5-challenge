# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress


# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_study=pd.merge(study_results, mouse_metadata,how="left",on="Mouse ID")



# Display the data table for preview
mouse_study.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mouse_count=len(mouse_study["Mouse ID"].unique())
mouse_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mouse_group=mouse_study.groupby(["Mouse ID","Timepoint"]).count()
mouse_dup=mouse_group.loc[mouse_group["Tumor Volume (mm3)"]>1,:]

mouse_dup.index[0]
# Out:
# ('g989', 0)

# %%
# Optional: Get all the data for the duplicate mouse ID. 

mouse_dupdata=mouse_study.loc[mouse_study["Mouse ID"].isin(mouse_dup.index[0])==True,:]
#mouse_dupdata=mouse_study.loc[mouse_study["Mouse ID"]=="g989"]

mouse_dupdata
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse=mouse_study[mouse_study["Mouse ID"].isin(mouse_dup.index[0])==False]
clean_mouse.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
mouse_list=clean_mouse["Mouse ID"].unique()
mouse_dropc=int(len(mouse_list))
mouse_dropc
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
mean=clean_mouse.groupby(clean_mouse["Drug Regimen"]).mean() ["Tumor Volume (mm3)"]
median=clean_mouse.groupby(clean_mouse["Drug Regimen"]).median() ["Tumor Volume (mm3)"]
var=clean_mouse.groupby(clean_mouse["Drug Regimen"]).var() ["Tumor Volume (mm3)"]
std=clean_mouse.groupby(clean_mouse["Drug Regimen"]).std() ["Tumor Volume (mm3)"]
sem=clean_mouse.groupby(clean_mouse["Drug Regimen"]).sem() ["Tumor Volume (mm3)"]

mouse_studystats=pd.DataFrame({"Mean Tumor Volume":mean,"Mean_Tumor_Volume":median,
                               "Tumor Volume Variance":var,"Tumor Volume Std. Dev.":std,
                               "Tumor Volume Std. Err.":sem})
mouse_studystats

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
# Out:
#               Mean Tumor Volume  Mean_Tumor_Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741          41.557809              24.947764
# Ceftamin              52.591172          51.776157              39.290177
# Infubinol             52.884795          51.820584              43.128684
# Ketapril              55.235638          53.698743              68.553577
# Naftisol              54.331565          52.509285              66.173479
# Placebo               54.033581          52.288934              61.168083
# Propriva              52.320930          50.446266              43.852013
# Ramicane              40.216745          40.673236              23.486704
# Stelasyn              54.233149          52.431737              59.450562
# Zoniferol             53.236507          51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   4.994774                0.329346
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen
reg_grp=clean_mouse.groupby("Drug Regimen")
tumor_vol=reg_grp["Tumor Volume (mm3)"]
mean=tumor_vol.mean()
median=tumor_vol.median()
var=tumor_vol.var()
std=tumor_vol.std()
sem=tumor_vol.sem()



# Using the aggregation method, produce the same summary statistics in a single line.
mouse_studystats1=pd.DataFrame({"mean":mean,"median":median,"var":var,"std":std,"sem":sem})
mouse_studystats1
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
mouse_num=clean_mouse.groupby(clean_mouse["Drug Regimen"]).count() ["Tumor Volume (mm3)"]
mouse_num.sort_values
mouse_chart=mouse_num.plot(kind="bar")
mouse_chart.set_xlabel("Drug Regimen")
mouse_chart.set_ylabel("Number of Mice Tested")
plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
x_axis=mouse_studystats.index

plt.bar(x_axis,mouse_num,color="b",alpha=.65,align="center")
tick_locations=[value for value in x_axis]
plt.xticks(tick_locations,x_axis,rotation="vertical")
plt.xlim(-0.75,len(x_axis),-0.25)
plt.ylim(0,max(mouse_num)+10)
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mouse_sex=clean_mouse.groupby("Sex").count()["Mouse ID"]
mouse_pie=mouse_sex.plot(kind="pie",autopct="%1.1f%%",y="Mouse ID")
mouse_pie.set_ylabel("Sex")
#plt.axis("equal")
plt.show()
plt.tight_layout()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex=clean_mouse["Sex"].value_counts()
#count=len(clean_mouse["Mouse ID"])
plt.pie(sex,labels=sex.index.values,autopct="%1.1f%%")
#plt.axis("equal")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
fin_vol=clean_mouse.set_index("Drug Regimen")

# Capomulin, Ramicane, Infubinol, and Ceftamin
fin_vol1=fin_vol.loc[["Capomulin", "Ramicane", "Infubinol", "Ceftamin"],["Mouse ID","Timepoint", "Tumor Volume (mm3)"]]

# Start by getting the last (greatest) timepoint for each mouse

fin_vol2=fin_vol1.groupby("Mouse ID").max()["Timepoint"]
fin_vol2 = fin_vol2.reset_index()
merged_data = fin_vol2.merge(clean_mouse,on=["Mouse ID","Timepoint"],how ="left")
merged_data
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      a203         45           67.973419                 2    Infubinol
# 1      a251         45           65.525743                 1    Infubinol
# 2      a275         45           62.999356                 3     Ceftamin
# 3      a411         45           38.407618                 1     Ramicane
# 4      a444         45           43.047543                 0     Ramicane
# ..      ...        ...                 ...               ...          ...
# 95     y769         45           68.594745                 4     Ceftamin
# 96     y793         45           31.896238                 2    Capomulin
# 97     y865         45           64.729837                 3     Ceftamin
# 98     z578         45           30.638696                 0     Ramicane
# 99     z581         45           62.754451                 3    Infubinol
#
#        Sex  Age_months  Weight (g)
# 0   Female          20          23
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)



# Create empty list to fill with tumor vol data (for plotting)

treatments_list=["Capomulin","Infubinol","Ramicane","Ceftamin"]
tumor_vol_data=[]

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
for row in treatments_list:
    final_tumor_vol=merged_data.loc[merged_data["Drug Regimen"]==row,"Tumor Volume (mm3)"]
    tumor_vol_data.append(final_tumor_vol)
    quartile=final_tumor_vol.quantile([.25,.5,.75])
    lowerq=quartile[0.25]
    upperq=quartile[0.75]
    iqr=upperq-lowerq
    
    # add subset 
    lower_bound=lowerq-(1.5*iqr)
    upper_bound=upperq+(1.5*iqr)
    
    # Determine outliers using upper and lower bounds
    outliers=final_tumor_vol.loc[(final_tumor_vol < lower_bound) | (final_tumor_vol > upper_bound)]
    print(f"{row}'s potential outliers: {outliers}")
#
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 15    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.


fig1, ax1=plt.subplots()
ax1.set_ylabel("Tumor Volume (mm3)")
ax1.set_xlabel(treatments_list)
for row in treatments_list:
    ax1.boxplot(tumor_vol_data)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
timepoint=clean_mouse.loc[clean_mouse["Drug Regimen"]=="Capomulin",:]
timepoint1=timepoint.loc[timepoint["Mouse ID"]=="l509",:]
timepoint2=timepoint1["Timepoint"]
timepoint3=timepoint2.max()
tumor_vol=timepoint1["Tumor Volume (mm3)"]
tumor_vol1=tumor_vol.max()
x_axis=np.arange(0,timepoint3,10)

plt.plot(timepoint2, tumor_vol, color="blue")
plt.title("Capomulin Treatment of mouse l509")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")

plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

capomulin_df=clean_mouse.loc[clean_mouse["Drug Regimen"]=="Capomulin",:]

tumor_vol=capomulin_df.groupby("Mouse ID").mean()
plt.scatter(tumor_vol["Weight (g)"],tumor_vol["Tumor Volume (mm3)"])
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x_value=round(tumor_vol["Weight (g)"],2)
y_value=round(tumor_vol["Tumor Volume (mm3)"],2)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value,y_value)
regress_values = x_value * slope + intercept
plt.scatter(x_value,y_value)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.plot(x_value,regress_values,"r-")

plt.show()
print(f"The correlation between mouse weight and the average tumor volume is {round(rvalue,2)}")
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
